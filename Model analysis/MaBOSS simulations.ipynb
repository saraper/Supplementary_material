# %% [markdown]
# # Stochastic simulations with MaBoSS

# %% [markdown]
# Import packages, model and define markers and regulators.

# %%
import ginsim 

gs_model = ginsim.load("IBD_logical_model.zginml")


#Prepare indexes with only output nodes

markers = ['BAD', 'CASP3', 'CASP8', 'FOXO3', 'RIPK3', 'ATG16L1', 'CXCL8', 'CDKN1A', 'MMP7', 'CLDN2', 'CXCL1', 'CXCL9', 'CXCL3', 'IFNL1', 'IFNA1', 'IDO1', 'SAA2', 'DEFA6', 'DEFA5', 'CAMP','IFNB', 'ISG15', 'LCN2', 'ISG20', 'REG3A' , 'S100A8', 'S100A9', 'MHC_II', 'IFNG', 'CXCL10', 'CCL20','IL1B', 'IL23','IL36A','TNF']
phen_arrays = [[ 'Apoptosis', 'Apoptosis', 'Apoptosis','Apoptosis', 'Necroptosis', 'Autophagy' , 'Proliferation', 'Proliferation' , 'Tissue repair', 'Immune cells', 'Immune cells' , 'Immune cells' ,'Immune cells','Immune cells', 'Immune cells', 'Immune cells', 'Immune cells', 'Immune cells','Immune cells', 'Immune cells','Immune cells','Immune cells','Immune cells','Immune cells', 'Immune cells', 'Immune cells', 'Immune cells', 'Immune cells','Th1', 'Th1', 'Th17/22', 'Th17/22', 'Th17/22', 'Th17/22', 'Th17/22'],
              markers]

regulators= ['IL22R', 'IL17R', 'TNFRSF1A', 'IFNGR','IFNAR','NOD1','NOD2','TLR3', 'TLR2', 'TLR4', 'TLR5', 'IL1R', 'IFNLR','ROS','AKT','COX2','DUOX2','FADD','IKBKB','IKBKG','IRAK_complex','JAK1_TYK2','JAK1_JAK2','JNK1', 'mTORC1', 'MYD88','NFKBIA', 'P38','PGE2','PI3K','PPARG','PTEN','PTPA','PTPN2','RIPK1','RIPK2','SOCS3','TAK1','TBK1','TICAM1','TNFAIP3','Tollip','TRADD','TRAF2','TRAF3IP2','TRAF6','TSC1', 'AP1', 'CREB1','IRF_complex', 'ISGF3', 'NFKB', 'STAT1','STAT3','IRF1']
reg_arrays = [['Receptor','Receptor','Receptor','Receptor','Receptor','Receptor','Receptor','Receptor','Receptor','Receptor','Receptor','Receptor','Receptor', 'ROS','Signaling protein', 'Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Signaling protein','Transcription factor','Transcription factor','Transcription factor','Transcription factor','Transcription factor','Transcription factor','Transcription factor','Transcription factor']
              ,regulators]

# %% [markdown]
# ### The probability of markers and regulators reaching certain stable states was simulated with MaBoSS. The simulations were performed separatly for the markers and regulators for better visualization.
#
# NB! The obtained probabilities can be altered each time the simulation is performed, although the difference is min

# %%
# Setting the initial conditions
mbs_TNF = ginsim.to_maboss(gs_model)
mbs_TNF.network.set_istate("TNFRSF1A", [0, 1])


# Update parameters and outputs of the model
mbs_TNF.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_TNF, markers)

# Simulations and presentation of the results
res_TNF_infl = mbs_TNF.run()
print("Figure 1. MaBoSS simulation output for markers upon TNF stimulation")
res_TNF_infl.plot_piechart()
# Out:
# Figure 1. MaBoSS simulation output for markers upon TNF stimulation

# %%
# Setting the initial conditions
mbs_TNF = ginsim.to_maboss(gs_model)
mbs_TNF.network.set_istate("TNFRSF1A", [0, 1])

# Update parameters and outputs of the model
mbs_TNF.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_TNF, regulators )

# Simulations and presentation of the results
res_TNF_infl = mbs_TNF.run()
print("Figure 2. MaBoSS simulation output for regulators upon TNF stimulation")
res_TNF_infl.plot_piechart()
# Out:
# Figure 2. MaBoSS simulation output for regulators upon TNF stimulation

# %%
# Setting the initial conditions
mbs_TNF_IL17 = ginsim.to_maboss(gs_model)
mbs_TNF_IL17.network.set_istate("TNFRSF1A", [0, 1])
mbs_TNF_IL17.network.set_istate("IL17R", [0, 1])


# Update parameters and outputs of the model
mbs_TNF_IL17.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_TNF_IL17, markers)

# Simulations and presentation of the results
res_TNF_IL17_infl = mbs_TNF_IL17.run()
print("Figure 3. MaBoSS simulation output for markers upon TNF and IL17 stimulation")
res_TNF_IL17_infl.plot_piechart()
# Out:
# Figure 3. MaBoSS simulation output for markers upon TNF and IL17 stimulation

# %%
# Setting the initial conditions
mbs_TNF_IL17 = ginsim.to_maboss(gs_model)
mbs_TNF_IL17.network.set_istate("TNFRSF1A", [0, 1])
mbs_TNF_IL17.network.set_istate("IL17R", [0, 1])

# Update parameters and outputs of the model
mbs_TNF_IL17.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_TNF_IL17, regulators)

# Simulations and presentation of the results
res_TNF_IL17_infl = mbs_TNF_IL17.run()
print("Figure 4. MaBoSS simulation output for regulators upon TNF and IL17 stimulation")
res_TNF_IL17_infl.plot_piechart()
# Out:
# Figure 4. MaBoSS simulation output for regulators upon TNF and IL17 stimulation

# %%
# Setting the initial conditions
mbs_cocktail =  ginsim.to_maboss(gs_model)
mbs_cocktail.network.set_istate("IL17R", [0, 1])
mbs_cocktail.network.set_istate("IL22R", [0, 1])
mbs_cocktail.network.set_istate("TNFRSF1A", [0, 1])
mbs_cocktail.network.set_istate("IFNGR", [0, 1])
mbs_cocktail.network.set_istate("IL1R", [0, 1])


# Update parameters and outputs of the model
mbs_cocktail.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_cocktail, markers)

# Simulations and presentation of the results
res_all_fate = mbs_cocktail.run()
print(" Figure 5. MaBoSS simulation output for markers upon cocktail-cytokine stimulation")
res_all_fate.plot_piechart()
# Out:
#  Figure 5. MaBoSS simulation output for markers upon cocktail-cytokine stimulation

# %%
# Setting the initial conditions
mbs_cocktail =  ginsim.to_maboss(gs_model)
mbs_cocktail.network.set_istate("IL17R", [0, 1])
mbs_cocktail.network.set_istate("IL22R", [0, 1])
mbs_cocktail.network.set_istate("TNFRSF1A", [0, 1])
mbs_cocktail.network.set_istate("IFNGR", [0, 1])
mbs_cocktail.network.set_istate("IL1R", [0, 1])


# Update parameters and outputs of the model
mbs_cocktail.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_cocktail, regulators)

# Simulations and presentation of the results
res_all_fate = mbs_cocktail.run()
print(" Figure 6. MaBoSS simulation output for regulators upon cocktail-cytokine stimulation")
res_all_fate.plot_piechart()
# Out:
#  Figure 6. MaBoSS simulation output for regulators upon cocktail-cytokine stimulation

# %%
# Setting the initial conditions
mbs_IFNS =  ginsim.to_maboss(gs_model)
mbs_IFNS.network.set_istate("IFNAR", [0, 1])
mbs_IFNS.network.set_istate("IFNGR", [0, 1])
mbs_IFNS.network.set_istate("IFNLR", [0, 1])


# Update parameters and outputs of the model
mbs_IFNS.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_IFNS, markers)

# Simulations and presentation of the results
res_all_fate = mbs_IFNS.run()
print(" Figure 7. MaBoSS simulation output for markers upon IFNs stimulation")
res_all_fate.plot_piechart()
# Out:
#  Figure 7. MaBoSS simulation output for markers upon IFNs stimulation

# %%
# Setting the initial conditions
mbs_IFNS =  ginsim.to_maboss(gs_model)
mbs_IFNS.network.set_istate("IFNAR", [0, 1])
mbs_IFNS.network.set_istate("IFNGR", [0, 1])
mbs_IFNS.network.set_istate("IFNLR", [0, 1])


# Update parameters and outputs of the model
mbs_IFNS.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_IFNS, regulators)

# Simulations and presentation of the results
res_all_fate = mbs_IFNS.run()
print(" Figure 8. MaBoSS simulation output for regulators upon IFNs stimulation")

res_all_fate.plot_piechart()
# Out:
#  Figure 8. MaBoSS simulation output for regulators upon IFNs stimulation

# %%
# Setting the initial conditions
mbs_ALL =  ginsim.to_maboss(gs_model)
mbs_ALL.network.set_istate("IFNAR", [0, 1])
mbs_ALL.network.set_istate("IFNGR", [0, 1])
mbs_ALL.network.set_istate("IFNLR", [0, 1])
mbs_ALL.network.set_istate("TNFRSF1A", [0, 1])
mbs_ALL.network.set_istate("IL22R", [0, 1])
mbs_ALL.network.set_istate("IL17R", [0, 1])
mbs_ALL.network.set_istate("NOD1", [0, 1])
mbs_ALL.network.set_istate("NOD2", [0, 1])
mbs_ALL.network.set_istate("TLR3", [0, 1])
mbs_ALL.network.set_istate("TLR2", [0, 1])
mbs_ALL.network.set_istate("TLR4", [0, 1])
mbs_ALL.network.set_istate("TLR5", [0, 1])
mbs_ALL.network.set_istate("IL1R", [0, 1])


# Update parameters and outputs of the model
mbs_ALL.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_ALL, markers)

# Simulations and presentation of the results
res_all_fate = mbs_ALL.run()
print(" Figure 9. MaBoSS simulation output for markers upon stimulation of every cytokine and bacterial component")

res_all_fate.plot_piechart()
# Out:
#  Figure 9. MaBoSS simulation output for markers upon stimulation of every cytokine and bacterial component

# %%
# Setting the initial conditions
mbs_ALL =  ginsim.to_maboss(gs_model)
mbs_ALL.network.set_istate("IFNAR", [0, 1])
mbs_ALL.network.set_istate("IFNGR", [0, 1])
mbs_ALL.network.set_istate("IFNLR", [0, 1])
mbs_ALL.network.set_istate("TNFRSF1A", [0, 1])
mbs_ALL.network.set_istate("IL22R", [0, 1])
mbs_ALL.network.set_istate("IL17R", [0, 1])
mbs_ALL.network.set_istate("NOD1", [0, 1])
mbs_ALL.network.set_istate("NOD2", [0, 1])
mbs_ALL.network.set_istate("TLR3", [0, 1])
mbs_ALL.network.set_istate("TLR2", [0, 1])
mbs_ALL.network.set_istate("TLR4", [0, 1])
mbs_ALL.network.set_istate("TLR5", [0, 1])
mbs_ALL.network.set_istate("IL1R", [0, 1])


# Update parameters and outputs of the model
mbs_ALL.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_ALL, regulators)

# Simulations and presentation of the results
res_all_fate = mbs_ALL.run()
print(" Figure 10. MaBoSS simulation output for regulators upon stimulation of every cytokine and bacterial component")
res_all_fate.plot_piechart()
# Out:
#  Figure 10. MaBoSS simulation output for regulators upon stimulation of every cytokine and bacterial component

# %% [markdown]
# ### The probability of markers and regulators reaching certain stable states after anti-TNF and/or anti-JAK2 perturbations was simulated with MaBoSS.

# %%
# Setting the initial conditions
mbs_TNF_IL17 = ginsim.to_maboss(gs_model)
mbs_TNF_IL17.network.set_istate("IL17R", [0, 1])
mbs_TNF_IL17.mutate("TNF_e","OFF")


# Update parameters and outputs of the model
mbs_TNF_IL17.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_TNF_IL17, markers)

# Simulations and presentation of the results
res_TNF_IL17_infl = mbs_TNF_IL17.run()
print("Figure 11. MaBoSS simulation output for markers upon TNF and IL17 stimulation, and anti-TNF perturbation")
res_TNF_IL17_infl.plot_piechart()
# Out:
# Figure 11. MaBoSS simulation output for markers upon TNF and IL17 stimulation, and anti-TNF perturbation

# %%
# Setting the initial conditions
mbs_TNF_IL17 = ginsim.to_maboss(gs_model)
mbs_TNF_IL17.network.set_istate("IL17R", [0, 1])
mbs_TNF_IL17.mutate("TNF_e","OFF")


# Update parameters and outputs of the model
mbs_TNF_IL17.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_TNF_IL17, regulators)

# Simulations and presentation of the results

res_TNF_IL17_infl = mbs_TNF_IL17.run()
print("Figure 12. MaBoSS simulation output for regulators upon TNF and IL17 stimulation, and anti-TNF perturbation")
res_TNF_IL17_infl.plot_piechart()
# Out:
# Figure 12. MaBoSS simulation output for regulators upon TNF and IL17 stimulation, and anti-TNF perturbation

# %%
# Setting the initial conditions
mbs_cocktail =  ginsim.to_maboss(gs_model)
mbs_cocktail.network.set_istate("IL17R", [0, 1])
mbs_cocktail.network.set_istate("IL22R", [0, 1])
mbs_cocktail.network.set_istate("IFNGR", [0, 1])
mbs_cocktail.network.set_istate("IL1R", [0, 1])
mbs_cocktail.mutate("TNF_e", "OFF")


# Update parameters and outputs of the model
mbs_cocktail.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_cocktail, markers)

# Simulations and presentation of the results
res_all_fate = mbs_cocktail.run()
print(" Figure 13. MaBoSS simulation output for markers upon cocktail-cytokine stimulation, and anti-TNF perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 13. MaBoSS simulation output for markers upon cocktail-cytokine stimulation, and anti-TNF perturbation

# %%
# Setting the initial conditions
mbs_cocktail =  ginsim.to_maboss(gs_model)
mbs_cocktail.network.set_istate("IL17R", [0, 1])
mbs_cocktail.network.set_istate("IL22R", [0, 1])
mbs_cocktail.network.set_istate("IFNGR", [0, 1])
mbs_cocktail.network.set_istate("IL1R", [0, 1])
mbs_cocktail.mutate("TNF_e", "OFF")


# Update parameters and outputs of the model
mbs_cocktail.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_cocktail, regulators)

# Simulations and presentation of the results
res_all_fate = mbs_cocktail.run()
print(" Figure 14. MaBoSS simulation output for regulators upon cocktail-cytokine stimulation, and anti-TNF perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 14. MaBoSS simulation output for regulators upon cocktail-cytokine stimulation, and anti-TNF perturbation

# %%
# Setting the initial conditions
mbs_cocktail =  ginsim.to_maboss(gs_model)
mbs_cocktail.network.set_istate("IL17R", [0, 1])
mbs_cocktail.network.set_istate("IL22R", [0, 1])
mbs_cocktail.network.set_istate("IFNGR", [0, 1])
mbs_cocktail.network.set_istate("IL1R", [0, 1])
mbs_cocktail.mutate("JAK1_JAK2", "OFF")


# Update parameters and outputs of the model
mbs_cocktail.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_cocktail, markers)

# Simulations and presentation of the results
res_all_fate = mbs_cocktail.run()
print(" Figure 15. MaBoSS simulation output for markers upon cocktail-cytokine stimulation, and anti-JAK2 perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 15. MaBoSS simulation output for markers upon cocktail-cytokine stimulation, and anti-JAK2 perturbation

# %%
# Setting the initial conditions
mbs_cocktail =  ginsim.to_maboss(gs_model)
mbs_cocktail.network.set_istate("IL17R", [0, 1])
mbs_cocktail.network.set_istate("IL22R", [0, 1])
mbs_cocktail.network.set_istate("IFNGR", [0, 1])
mbs_cocktail.network.set_istate("IL1R", [0, 1])
mbs_cocktail.mutate("JAK1_JAK2", "OFF")


# Update parameters and outputs of the model
mbs_cocktail.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_cocktail, regulators)

# Simulations and presentation of the results
res_all_fate = mbs_cocktail.run()
print(" Figure 16. MaBoSS simulation output for regulators upon cocktail-cytokine stimulation, and anti-JAK2 perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 16. MaBoSS simulation output for regulators upon cocktail-cytokine stimulation, and anti-JAK2 perturbation

# %%
# Setting the initial conditions
mbs_cocktail =  ginsim.to_maboss(gs_model)
mbs_cocktail.network.set_istate("IL17R", [0, 1])
mbs_cocktail.network.set_istate("IL22R", [0, 1])
mbs_cocktail.network.set_istate("IFNGR", [0, 1])
mbs_cocktail.network.set_istate("IL1R", [0, 1])
mbs_cocktail.mutate("TNF_e", "OFF")
mbs_cocktail.mutate("JAK1_JAK2", "OFF")


# Update parameters and outputs of the model
mbs_cocktail.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_cocktail, markers)

# Simulations and presentation of the results
res_all_fate = mbs_cocktail.run()
print(" Figure 17. MaBoSS simulation output for markers upon cocktail-cytokine stimulation, and anti-TNF and anti-JAK2 perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 17. MaBoSS simulation output for markers upon cocktail-cytokine stimulation, and anti-TNF and anti-JAK2 perturbation

# %%
# Setting the initial conditions
mbs_cocktail =  ginsim.to_maboss(gs_model)
mbs_cocktail.network.set_istate("IL17R", [0, 1])
mbs_cocktail.network.set_istate("IL22R", [0, 1])
mbs_cocktail.network.set_istate("IFNGR", [0, 1])
mbs_cocktail.network.set_istate("IL1R", [0, 1])
mbs_cocktail.mutate("TNF_e", "OFF")
mbs_cocktail.mutate("JAK1_JAK2", "OFF")


# Update parameters and outputs of the model
mbs_cocktail.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_cocktail, regulators)

# Simulations and presentation of the results
res_all_fate = mbs_cocktail.run()
print(" Figure 18. MaBoSS simulation output for regulators upon cocktail-cytokine stimulation, and anti-TNF and anti-JAK2 perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 18. MaBoSS simulation output for regulators upon cocktail-cytokine stimulation, and anti-TNF and anti-JAK2 perturbation

# %%
# Setting the initial conditions
mbs_IFNS =  ginsim.to_maboss(gs_model)
mbs_IFNS.network.set_istate("IFNAR", [0, 1])
mbs_IFNS.network.set_istate("IFNGR", [0, 1])
mbs_IFNS.network.set_istate("IFNLR", [0, 1])
mbs_IFNS.mutate("JAK1_JAK2", "OFF")


# Update parameters and outputs of the model
mbs_IFNS.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_IFNS, markers)


# Simulations and presentation of the results
res_all_fate = mbs_IFNS.run()
print(" Figure 19. MaBoSS simulation output for markers upon IFNs stimulation, and anti-JAK2 perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 19. MaBoSS simulation output for markers upon IFNs stimulation, and anti-JAK2 perturbation

# %%
# Setting the initial conditions
mbs_IFNS =  ginsim.to_maboss(gs_model)
mbs_IFNS.network.set_istate("IFNAR", [0, 1])
mbs_IFNS.network.set_istate("IFNGR", [0, 1])
mbs_IFNS.network.set_istate("IFNLR", [0, 1])
mbs_IFNS.mutate("JAK1_JAK2", "OFF")


# Update parameters and outputs of the model
mbs_IFNS.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_IFNS, regulators)


# Simulations and presentation of the results
res_all_fate = mbs_IFNS.run()
print(" Figure 20. MaBoSS simulation output for regulators upon IFNs stimulation, and anti-JAK2 perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 20. MaBoSS simulation output for regulators upon IFNs stimulation, and anti-JAK2 perturbation

# %%
# Setting the initial conditions
mbs_ALL =  ginsim.to_maboss(gs_model)
mbs_ALL.network.set_istate("IFNAR", [0, 1])
mbs_ALL.network.set_istate("IFNGR", [0, 1])
mbs_ALL.network.set_istate("IFNLR", [0, 1])
mbs_ALL.network.set_istate("IL22R", [0, 1])
mbs_ALL.network.set_istate("IL17R", [0, 1])
mbs_ALL.network.set_istate("NOD1", [0, 1])
mbs_ALL.network.set_istate("NOD2", [0, 1])
mbs_ALL.network.set_istate("TLR3", [0, 1])
mbs_ALL.network.set_istate("TLR2", [0, 1])
mbs_ALL.network.set_istate("TLR4", [0, 1])
mbs_ALL.network.set_istate("TLR5", [0, 1])
mbs_ALL.network.set_istate("IL1R", [0, 1])
mbs_ALL.mutate("TNF_e", "OFF")


# Update parameters and outputs of the model
mbs_ALL.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_ALL, markers)

# Simulations and presentation of the results
res_all_fate = mbs_ALL.run()
print(" Figure 21. MaBoSS simulation output for markers upon stimulation of every cytokine and bacterial component, and anti-TNF perturbation")

res_all_fate.plot_piechart()
# Out:
#  Figure 21. MaBoSS simulation output for markers upon stimulation of every cytokine and bacterial component, and anti-TNF perturbation

# %%
# Setting the initial conditions
mbs_ALL =  ginsim.to_maboss(gs_model)
mbs_ALL.network.set_istate("IFNAR", [0, 1])
mbs_ALL.network.set_istate("IFNGR", [0, 1])
mbs_ALL.network.set_istate("IFNLR", [0, 1])
mbs_ALL.network.set_istate("IL22R", [0, 1])
mbs_ALL.network.set_istate("IL17R", [0, 1])
mbs_ALL.network.set_istate("NOD1", [0, 1])
mbs_ALL.network.set_istate("NOD2", [0, 1])
mbs_ALL.network.set_istate("TLR3", [0, 1])
mbs_ALL.network.set_istate("TLR2", [0, 1])
mbs_ALL.network.set_istate("TLR4", [0, 1])
mbs_ALL.network.set_istate("TLR5", [0, 1])
mbs_ALL.network.set_istate("IL1R", [0, 1])
mbs_ALL.mutate("TNF_e", "OFF")


# Update parameters and outputs of the model
mbs_ALL.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_ALL, regulators)

# Simulations and presentation of the results
res_all_fate = mbs_ALL.run()
print(" Figure 22. MaBoSS simulation output for regulators upon stimulation of every cytokine and bacterial component, and anti-TNF perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 22. MaBoSS simulation output for regulators upon stimulation of every cytokine and bacterial component, and anti-TNF perturbation

# %%
# Setting the initial conditions
mbs_ALL =  ginsim.to_maboss(gs_model)
mbs_ALL.network.set_istate("IFNAR", [0, 1])
mbs_ALL.network.set_istate("IFNGR", [0, 1])
mbs_ALL.network.set_istate("IFNLR", [0, 1])
mbs_ALL.network.set_istate("IL22R", [0, 1])
mbs_ALL.network.set_istate("IL17R", [0, 1])
mbs_ALL.network.set_istate("NOD1", [0, 1])
mbs_ALL.network.set_istate("NOD2", [0, 1])
mbs_ALL.network.set_istate("TLR3", [0, 1])
mbs_ALL.network.set_istate("TLR2", [0, 1])
mbs_ALL.network.set_istate("TLR4", [0, 1])
mbs_ALL.network.set_istate("TLR5", [0, 1])
mbs_ALL.network.set_istate("IL1R", [0, 1])
mbs_ALL.mutate("JAK1_JAK2", "OFF")



# Update parameters and outputs of the model
mbs_ALL.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_ALL, markers)


# Simulations and presentation of the results
res_all_fate = mbs_ALL.run()
print(" Figure 23. MaBoSS simulation output for markers upon stimulation of every cytokine and bacterial component, and anti-JAK2 perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 23. MaBoSS simulation output for markers upon stimulation of every cytokine and bacterial component, and anti-JAK2 perturbation

# %%
# Setting the initial conditions
mbs_ALL =  ginsim.to_maboss(gs_model)
mbs_ALL.network.set_istate("IFNAR", [0, 1])
mbs_ALL.network.set_istate("IFNGR", [0, 1])
mbs_ALL.network.set_istate("IFNLR", [0, 1])
mbs_ALL.network.set_istate("IL22R", [0, 1])
mbs_ALL.network.set_istate("IL17R", [0, 1])
mbs_ALL.network.set_istate("NOD1", [0, 1])
mbs_ALL.network.set_istate("NOD2", [0, 1])
mbs_ALL.network.set_istate("TLR3", [0, 1])
mbs_ALL.network.set_istate("TLR2", [0, 1])
mbs_ALL.network.set_istate("TLR4", [0, 1])
mbs_ALL.network.set_istate("TLR5", [0, 1])
mbs_ALL.network.set_istate("IL1R", [0, 1])
mbs_ALL.mutate("JAK1_JAK2", "OFF")



# Update parameters and outputs of the model
mbs_ALL.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_ALL, regulators)

# Simulations and presentation of the results
res_all_fate = mbs_ALL.run()
print(" Figure 24. MaBoSS simulation output for regulators upon stimulation of every cytokine and bacterial component, and anti-JAK2 perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 24. MaBoSS simulation output for regulators upon stimulation of every cytokine and bacterial component, and anti-JAK2 perturbation

# %%
# Setting the initial conditions
mbs_ALL =  ginsim.to_maboss(gs_model)
mbs_ALL.network.set_istate("IFNAR", [0, 1])
mbs_ALL.network.set_istate("IFNGR", [0, 1])
mbs_ALL.network.set_istate("IFNLR", [0, 1])
mbs_ALL.network.set_istate("IL22R", [0, 1])
mbs_ALL.network.set_istate("IL17R", [0, 1])
mbs_ALL.network.set_istate("NOD1", [0, 1])
mbs_ALL.network.set_istate("NOD2", [0, 1])
mbs_ALL.network.set_istate("TLR3", [0, 1])
mbs_ALL.network.set_istate("TLR2", [0, 1])
mbs_ALL.network.set_istate("TLR4", [0, 1])
mbs_ALL.network.set_istate("TLR5", [0, 1])
mbs_ALL.network.set_istate("IL1R", [0, 1])
mbs_ALL.mutate("JAK1_JAK2", "OFF")
mbs_ALL.mutate("TNF_e", "OFF")


# Update parameters and outputs of the model
mbs_ALL.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_ALL, markers)

# Simulations and presentation of the results
res_all_fate = mbs_ALL.run()
print(" Figure 25. MaBoSS simulation output for markers upon stimulation of every cytokine and bacterial component, and anti-TNF and anti-JAK2 perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 25. MaBoSS simulation output for markers upon stimulation of every cytokine and bacterial component, and anti-TNF and anti-JAK2 perturbation

# %%
# Setting the initial conditions
mbs_ALL =  ginsim.to_maboss(gs_model)
mbs_ALL.network.set_istate("IFNAR", [0, 1])
mbs_ALL.network.set_istate("IFNGR", [0, 1])
mbs_ALL.network.set_istate("IFNLR", [0, 1])
mbs_ALL.network.set_istate("IL22R", [0, 1])
mbs_ALL.network.set_istate("IL17R", [0, 1])
mbs_ALL.network.set_istate("NOD1", [0, 1])
mbs_ALL.network.set_istate("NOD2", [0, 1])
mbs_ALL.network.set_istate("TLR3", [0, 1])
mbs_ALL.network.set_istate("TLR2", [0, 1])
mbs_ALL.network.set_istate("TLR4", [0, 1])
mbs_ALL.network.set_istate("TLR5", [0, 1])
mbs_ALL.network.set_istate("IL1R", [0, 1])
mbs_ALL.mutate("JAK1_JAK2", "OFF")
mbs_ALL.mutate("TNF_e", "OFF")


# Update parameters and outputs of the model
mbs_ALL.update_parameters(sample_count=10000,time_tick=0.1, max_time=30)
maboss.set_output(mbs_ALL, regulators)

# Simulations and presentation of the results
res_all_fate = mbs_ALL.run()
print(" Figure 26. MaBoSS simulation output for regulators upon stimulation of every cytokine and bacterial component, and anti-TNF and anti-JAK2 perturbation")
res_all_fate.plot_piechart()
# Out:
#  Figure 26. MaBoSS simulation output for regulators upon stimulation of every cytokine and bacterial component, and anti-TNF and anti-JAK2 perturbation
